# %%
model = 'rfc'
title = 'results_1620697462.279475'
columns = ['$TF_{us}$ + $TF_{un}$',
           '$TF_{us}$',
           '$TF_{un}$',
           '$Q_{c}$',
           '$Q_{p}$',
           '$Q_{c}$ + $Q_{p}$',
           '$Q_{l}$',
           '$Q_{d}$',
           '$Q_{l}$ + $Q_{d}$',
           '$Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$',
           '$TF_{bs}$ + $TF_{bn}$',
           '$TF_{bs}$',
           '$TF_{bn}$',
           '$TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$',
           '$TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$',]
with open(f'./data/{model}/reports/{title}.txt', 'r') as fp:
    lines = fp.readlines()
    for i in range(len(columns)):
        string_to_print = '{%s} &' % columns[i]
        print(string_to_print, lines[i], end='')
# Out:
# {$TF_{us}$ + $TF_{un}$} & {0.97377}&{0.80366}&{0.78209}&{0.97683}&{0.86732}&{0.88175} \\
# {$TF_{us}$} & {0.98758}&{0.75042}&{0.69947}&{0.99032}&{0.81880}&{0.85380} \\
# {$TF_{un}$} & {0.96146}&{0.73240}&{0.67647}&{0.97009}&{0.79393}&{0.83457} \\
# {$Q_{c}$} & {0.56871}&{0.62006}&{0.82299}&{0.31554}&{0.67255}&{0.41787} \\
# {$Q_{p}$} & {0.55161}&{0.56565}&{0.79813}&{0.28827}&{0.65228}&{0.38147} \\
# {$Q_{c}$ + $Q_{p}$} & {0.56359}&{0.61454}&{0.83209}&{0.29326}&{0.67196}&{0.39675} \\
# {$Q_{l}$} & {0.57894}&{0.54997}&{0.62594}&{0.50088}&{0.60145}&{0.52417} \\
# {$Q_{d}$} & {0.60904}&{0.55206}&{0.54358}&{0.61701}&{0.57434}&{0.58264} \\
# {$Q_{l}$ + $Q_{d}$} & {0.58977}&{0.56725}&{0.64786}&{0.50587}&{0.61740}&{0.53472} \\
# {$Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$} & {0.61123}&{0.58299}&{0.63770}&{0.55513}&{0.62409}&{0.56859} \\
# {$TF_{bs}$ + $TF_{bn}$} & {0.80493}&{0.99878}&{0.99920}&{0.73402}&{0.89154}&{0.84596} \\
# {$TF_{bs}$} & {0.97961}&{0.70303}&{0.62005}&{0.98592}&{0.75932}&{0.82076} \\
# {$TF_{bn}$} & {0.97376}&{0.77770}&{0.74492}&{0.97801}&{0.84403}&{0.86639} \\
# {$TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$} & {0.98068}&{0.88204}&{0.88021}&{0.98094}&{0.92767}&{0.92882} \\
# {$TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$} & {0.97519}&{0.80660}&{0.78583}&{0.97801}&{0.87016}&{0.88399} \\
