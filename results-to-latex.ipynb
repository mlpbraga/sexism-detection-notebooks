# %%
import pickle

report = pickle.load( open('./data/results', 'rb'))

# %%
mean_results = report

# %%
def map_key_to_latex(key):
    if 'B_SVM' in key:
        return 'Baseline SVM'
    if 'B_LR' in key:
        return 'Baseline LR'
    if 'TFus' in key:
        return '$TF_{us}$'
    if 'TFun' in key:
        return '$TF_{un}$'
    if 'TFbs' in key:
        return '$TF_{bs}$'
    if 'TFbn' in key:
        return '$TF_{bn}$'
    if 'TFuQ' in key:
        return '$TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$'
    if 'TFb' in key:
        return '$TF_{bs}$ + $TF_{bn}$'
    if 'TFu' in key:
        return '$TF_{us}$ + $TF_{un}$'
    if 'CQWQ' in key:
        return '$Q_{c}$ + $Q_{p}$'
    if 'LD' in key:
        return '$Q_{l}$ + $Q_{d}$'
    if 'L' in key:
        return '$Q_{l}$'
    if 'D' in key:
        return '$Q_{d}$'
    if 'WQ' in key:
        return '$Q_{p}$'
    if 'CQ' in key:
        return '$Q_{c}$'
    if 'TF' in key:
        return '$TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$'
    if 'Q' in key:
        return '$Q_{l}$ + $Q_{d}$ + $Q_{c}$ + $Q_{p}$'
    else:
        return key

def print_to_latex(report):
    return ('&{%.5f}&{%.5f}&{%.5f}&{%.5f}&{%.5f}&{%.5f} \\\\' % ((report["precision"]["1"]),
                                                                (report["precision"]["0"]),
                                                                (report["recall"]["1"]),
                                                                (report["recall"]["0"]),
                                                                (report["f1"]["1"]),
                                                                (report["f1"]["0"])))

columns = ['$TF_{us}$',
           '$TF_{un}$',
           '$TF_{bs}$',
           '$TF_{bn}$',
           '$Q_{l}$',
           '$Q_{d}$',
           '$Q_{c}$',
           '$Q_{p}$',
           '$Q_{c}$ + $Q_{p}$',
           '$Q_{l}$ + $Q_{d}$',
           '$Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$',
           '$TF_{us}$ + $TF_{un}$',
           '$TF_{bs}$ + $TF_{bn}$',
           '$TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$',
           '$TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$',]

print('SVM')
result_latex = []
for key in mean_results.keys():
    if 'SVM' in key:
        print(map_key_to_latex(key),print_to_latex(mean_results[key]))

print('KNN')
result_latex = []
for key in mean_results.keys():
    if 'KNN' in key:
        print(map_key_to_latex(key),print_to_latex(mean_results[key]))

print('RFC')   
result_latex = []
for key in mean_results.keys():
    if 'RFC' in key:
        print(map_key_to_latex(key),print_to_latex(mean_results[key]))
# Out:
# SVM
# $TF_{us}$ &{0.95534}&{0.81824}&{0.80631}&{0.95855}&{0.87452}&{0.88285} \\
# $TF_{un}$ &{0.92205}&{0.78447}&{0.76791}&{0.92863}&{0.83795}&{0.85048} \\
# $TF_{bs}$ &{0.77546}&{0.55670}&{0.35829}&{0.88595}&{0.49012}&{0.68376} \\
# $TF_{bn}$ &{0.59838}&{0.79331}&{0.92471}&{0.31770}&{0.72659}&{0.45370} \\
# $Q_{l}$ &{0.58112}&{0.52410}&{0.50374}&{0.60082}&{0.53967}&{0.55985} \\
# $Q_{d}$ &{0.62412}&{0.50791}&{0.28503}&{0.81129}&{0.39134}&{0.62472} \\
# $Q_{c}$ &{0.53928}&{0.53557}&{0.81497}&{0.23457}&{0.64906}&{0.32625} \\
# $Q_{p}$ &{0.53924}&{0.54124}&{0.83048}&{0.21987}&{0.65389}&{0.31271} \\
# $Q_{c}$ + $Q_{p}$ &{0.54071}&{0.53826}&{0.80963}&{0.24397}&{0.64839}&{0.33576} \\
# $Q_{l}$ + $Q_{d}$ &{0.60220}&{0.52493}&{0.43957}&{0.68078}&{0.50819}&{0.59278} \\
# $Q_{l}$ + $Q_{d}$ + $Q_{c}$ + $Q_{p}$ &{0.54706}&{0.55174}&{0.79733}&{0.27425}&{0.64890}&{0.36639} \\
# $TF_{us}$ + $TF_{un}$ &{0.97547}&{0.89242}&{0.89305}&{0.97531}&{0.93244}&{0.93202} \\
# $TF_{bs}$ + $TF_{bn}$ &{0.62697}&{0.81116}&{0.91497}&{0.40153}&{0.74407}&{0.53716} \\
# $TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$ &{0.97733}&{0.89789}&{0.89893}&{0.97707}&{0.93649}&{0.93581} \\
# $TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$ &{0.97853}&{0.90043}&{0.90160}&{0.97825}&{0.93849}&{0.93773} \\
# KNN
# $TF_{us}$ &{0.91422}&{0.89469}&{0.89604}&{0.89571}&{0.90055}&{0.88940} \\
# $TF_{un}$ &{0.90220}&{0.89479}&{0.89529}&{0.88283}&{0.89394}&{0.88294} \\
# $TF_{bs}$ &{0.73642}&{0.71079}&{0.67225}&{0.60958}&{0.63678}&{0.56950} \\
# $TF_{bn}$ &{0.68809}&{0.77320}&{0.74642}&{0.53333}&{0.64649}&{0.56003} \\
# $Q_{l}$ &{0.56646}&{0.51067}&{0.51877}&{0.55121}&{0.52906}&{0.52084} \\
# $Q_{d}$ &{0.56986}&{0.49272}&{0.54604}&{0.50794}&{0.53445}&{0.47820} \\
# $Q_{c}$ &{0.61639}&{0.57913}&{0.61845}&{0.57684}&{0.61730}&{0.57785} \\
# $Q_{p}$ &{0.55014}&{0.50379}&{0.54727}&{0.50523}&{0.54511}&{0.50093} \\
# $Q_{c}$ + $Q_{p}$ &{0.81246}&{0.75570}&{0.76283}&{0.80635}&{0.78683}&{0.78017} \\
# $Q_{l}$ + $Q_{d}$ &{0.67727}&{0.62320}&{0.63513}&{0.65802}&{0.65108}&{0.63608} \\
# $Q_{l}$ + $Q_{d}$ + $Q_{c}$ + $Q_{p}$ &{0.99536}&{0.96160}&{0.96385}&{0.99506}&{0.97935}&{0.97804} \\
# $TF_{us}$ + $TF_{un}$ &{0.98432}&{0.92685}&{0.92866}&{0.98277}&{0.95528}&{0.95352} \\
# $TF_{bs}$ + $TF_{bn}$ &{0.76855}&{0.79300}&{0.77262}&{0.66878}&{0.73192}&{0.68065} \\
# $TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$ &{0.98471}&{0.92861}&{0.93048}&{0.98319}&{0.95644}&{0.95465} \\
# $TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$ &{1.00000}&{0.99590}&{0.99626}&{1.00000}&{0.99812}&{0.99795} \\
# RFC
# $TF_{us}$ &{0.97371}&{0.80763}&{0.78840}&{0.97660}&{0.87131}&{0.88411} \\
# $TF_{un}$ &{0.95398}&{0.79082}&{0.76920}&{0.95920}&{0.85167}&{0.86691} \\
# $TF_{bs}$ &{0.75085}&{0.61398}&{0.49380}&{0.75520}&{0.55294}&{0.61926} \\
# $TF_{bn}$ &{0.59195}&{0.89741}&{0.97246}&{0.26302}&{0.73592}&{0.40668} \\
# $Q_{l}$ &{0.58359}&{0.55021}&{0.61529}&{0.51734}&{0.59902}&{0.53326} \\
# $Q_{d}$ &{0.60999}&{0.54574}&{0.51914}&{0.63510}&{0.56091}&{0.58704} \\
# $Q_{c}$ &{0.58497}&{0.64860}&{0.82380}&{0.35738}&{0.68411}&{0.46070} \\
# $Q_{p}$ &{0.56782}&{0.56387}&{0.72070}&{0.39694}&{0.63517}&{0.46586} \\
# $Q_{c}$ + $Q_{p}$ &{0.61883}&{0.71068}&{0.84043}&{0.43086}&{0.71279}&{0.53643} \\
# $Q_{l}$ + $Q_{d}$ &{0.63825}&{0.59587}&{0.62230}&{0.61223}&{0.63017}&{0.60393} \\
# $Q_{l}$ + $Q_{d}$ + $Q_{c}$ + $Q_{p}$ &{0.70150}&{0.68862}&{0.72893}&{0.65897}&{0.71493}&{0.67344} \\
# $TF_{us}$ + $TF_{un}$ &{0.97327}&{0.86357}&{0.86000}&{0.97402}&{0.91312}&{0.91546} \\
# $TF_{bs}$ + $TF_{bn}$ &{0.60093}&{0.91803}&{0.97668}&{0.28695}&{0.74406}&{0.43721} \\
# $TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$ &{0.97293}&{0.86876}&{0.86620}&{0.97349}&{0.91646}&{0.91814} \\
# $TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$ &{0.97947}&{0.86363}&{0.85920}&{0.98019}&{0.91539}&{0.91822} \\

# %%
tests = pickle.load( open('./data/wilcoxon', 'rb'))

# %%
baselines = ['SVM_TFu', 'SVM_TF', 'SVM_TFuQ']

# %%
for key in tests.keys():
    for method in baselines:
        if method in key and tests[key] != 0.001953125:
            print(key,'&' , tests[key], '\\\\')
            print('\\hline')
            break
# Out:
# SVM_TFbs x KNN_TFbn & 0.02734375 \\
# \hline
# SVM_TFbs x KNN_L & 0.130859375 \\
# \hline
# SVM_TFbs x KNN_D & 0.10546875 \\
# \hline
# SVM_TFbs x KNN_WQ & 0.009765625 \\
# \hline
# SVM_TFbs x BERT & 0.130859375 \\
# \hline
# KNN_TFbs x SVM_TFbn & 0.232421875 \\
# \hline
# SVM_TFbn x KNN_TFbn & 1.0 \\
# \hline
# SVM_TFbn x KNN_TFb & 0.556640625 \\
# \hline
# KNN_TFbn x SVM_TFb & 1.0 \\
# \hline
# SVM_TFb x KNN_TFb & 0.556640625 \\
# \hline
# SVM_TFb x RFC_TFb & 0.4921875 \\
# \hline

# %%
for key in tests.keys():
    model = 'SMV'
    if 'BERT' in key and 'SVM' in key:
        aux = key.split(' x ')
        print()
# Out:
# $TF_{us}$ x BERT & 0.001953125 \\
# $TF_{us}$ x BERT & 0.001953125 \\
# $TF_{us}$ x BERT & 0.001953125 \\
# $TF_{un}$ x BERT & 0.001953125 \\
# $TF_{un}$ x BERT & 0.001953125 \\
# $TF_{un}$ x BERT & 0.001953125 \\
# $TF_{bs}$ x BERT & 0.130859375 \\
# $TF_{bs}$ x BERT & 0.001953125 \\
# $TF_{bs}$ x BERT & 0.625 \\
# $TF_{bn}$ x BERT & 0.001953125 \\
# $TF_{bn}$ x BERT & 0.02734375 \\
# $TF_{bn}$ x BERT & 0.001953125 \\
# $Q_{l}$ x BERT & 0.16015625 \\
# $Q_{l}$ x BERT & 0.556640625 \\
# $Q_{l}$ x BERT & 0.001953125 \\
# $Q_{d}$ x BERT & 0.001953125 \\
# $Q_{d}$ x BERT & 0.556640625 \\
# $Q_{d}$ x BERT & 0.00390625 \\
# $Q_{c}$ x BERT & 0.001953125 \\
# $Q_{c}$ x BERT & 0.001953125 \\
# $Q_{c}$ x BERT & 0.001953125 \\
# $Q_{p}$ x BERT & 0.001953125 \\
# $Q_{p}$ x BERT & 0.322265625 \\
# $Q_{p}$ x BERT & 0.001953125 \\
# $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# $Q_{l}$ + $Q_{d}$ x BERT & 0.625 \\
# $Q_{l}$ + $Q_{d}$ x BERT & 0.001953125 \\
# $Q_{l}$ + $Q_{d}$ x BERT & 0.001953125 \\
# $Q_{l}$ + $Q_{d}$ + $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# $Q_{l}$ + $Q_{d}$ + $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# $Q_{l}$ + $Q_{d}$ + $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ x BERT & 0.001953125 \\
# $TF_{bs}$ + $TF_{bn}$ x BERT & 0.001953125 \\
# $TF_{bs}$ + $TF_{bn}$ x BERT & 0.001953125 \\
# $TF_{bs}$ + $TF_{bn}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ + $TF_{bs}$ + $TF_{bn}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# $TF_{us}$ + $TF_{un}$ + $Q_{l}$ + $Q_{s}$ + $Q_{c}$ + $Q_{p}$ x BERT & 0.001953125 \\
# BERT x Baseline SVM & 0.001953125 \\
# BERT x Baseline LR & 0.001953125 \\
